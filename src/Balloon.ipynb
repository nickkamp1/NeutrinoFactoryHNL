# %% [markdown]
# This notebook is for analysis of of the full parameter space with the balloon setup

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
output_folder = "/n/holylfs05/LABS/arguelles_delgado_lab/Everyone/nkamp/Pheno/HNLs/NeutrinoFactoryHNL/data/scan_results/"
for min_photons,color in zip([10,100,500],['green','orange','red']):
    output_file = f"{output_folder}combined_{min_photons}.npz"
    output_data = np.load(output_file)
    plt.contour(output_data["m_N"], output_data["U2"], output_data["events"], levels=[1, 100], norm=LogNorm(), colors=color, linestyles=['--', '-'])
    plt.plot([], [], color=color, label=f'{min_photons} photons')
plt.plot([],[],color='black', linestyle='--', label='1 event')
plt.plot([],[],color='black', linestyle='-', label='100 events')
plt.xlabel(r'HNL Mass $m_N$ [GeV]')
plt.ylabel(r'$|U_\mu|^2$')
plt.xscale('log')
plt.yscale('log')

# Seesaw bound
U2_seesaw = 5e-11 / output_data["m_N"]
plt.fill_between(output_data["m_N"], 1e-20, U2_seesaw, color='gray', alpha=0.2)
plt.plot(output_data["m_N"], U2_seesaw, 'gray', linestyle='--')
plt.legend(loc='upper left',ncol=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 for min_photons,color in zip([10,100,500],['green','orange','red']):
#       3     output_file = f"{output_folder}combined_{min_photons}.npz"
# ----> 4     output_data = np.load(output_file)
#       5     plt.contour(output_data["m_N"], output_data["U2"], output_data["events"], levels=[1, 100], norm=LogNorm(), colors=color, linestyles=['--', '-'])
#       6     plt.plot([], [], color=color, label=f'{min_photons} photons')
#
# File ~/anaconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# ...
